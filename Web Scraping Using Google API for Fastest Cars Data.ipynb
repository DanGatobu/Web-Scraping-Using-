# %% [markdown]
# # Webscraping using Google api

# %%
# %pip install beautifulsoup4
# %pip install html5lib


# %pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#   Using cached html5lib-1.1-py2.py3-none-any.whl (112 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/html5lib/

# %%
# url=https://site.financialmodelingprep.com/developer/docs/#Company-Financial-Ratios.

# %%
import requests

# %% [markdown]
# ### html body to render search box in page later

# %%
# <script async src="https://cse.google.com/cse.js?cx=56e09f963ccb2469d">
# </script>
# <div class="gcse-search"></div>

# %%
def parameters():
    pass

# %%
apikey='AIzaSyDgbr6fy7dt7rLTHVuJW6T0tX4frDrHNPQ'
engineid='56e09f963ccb2469d'

# %%
from bs4 import BeautifulSoup as sp
search='top fastest cars'
google_link='https://www.googleapis.com/customsearch/v1'

# %%
parameters={'key':apikey,'cx':engineid,'q':search}

# %%
value=requests.get(google_link,params=parameters)

# %%
if value.status_code!=200:
    print('failed')
else:
    print("you can continue")
# Out:
# you can continue

# %%
print(value)
# Out:
# <Response [200]>

# %%
data=value.content
dataa=data.decode('utf-8')

# %%
dataa
# Out:
# '{\n  "kind": "customsearch#search",\n  "url": {\n    "type": "application/json",\n    "template": "https://www.googleapis.com/customsearch/v1?q={searchTerms}&num={count?}&start={startIndex?}&lr={language?}&safe={safe?}&cx={cx?}&sort={sort?}&filter={filter?}&gl={gl?}&cr={cr?}&googlehost={googleHost?}&c2coff={disableCnTwTranslation?}&hq={hq?}&hl={hl?}&siteSearch={siteSearch?}&siteSearchFilter={siteSearchFilter?}&exactTerms={exactTerms?}&excludeTerms={excludeTerms?}&linkSite={linkSite?}&orTerms={orTerms?}&relatedSite={relatedSite?}&dateRestrict={dateRestrict?}&lowRange={lowRange?}&highRange={highRange?}&searchType={searchType}&fileType={fileType?}&rights={rights?}&imgSize={imgSize?}&imgType={imgType?}&imgColorType={imgColorType?}&imgDominantColor={imgDominantColor?}&alt=json"\n  },\n  "queries": {\n    "request": [\n      {\n        "title": "Google Custom Search - top fastest cars",\n        "totalResults": "566000000",\n        "searchTerms": "top fastest cars",\n        "count": 10,
# ...

# %%
soup = BeautifulSoup(value, 'html.parser')
soup
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 soup = BeautifulSoup(value, 'html.parser')
#       2 soup
#
# File ~\anaconda3\Lib\site-packages\bs4\__init__.py:315, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     313 if hasattr(markup, 'read'):        # It's a file-type object.
#     314     markup = markup.read()
# --> 315 elif len(markup) <= 256 and (
#     316         (isinstance(markup, bytes) and not b'<' in markup)
#     317         or (isinstance(markup, str) and not '<' in markup)
#     318 ):
#     319     # Issue warnings for a couple beginner problems
#     320     # involving passing non-markup to Beautiful Soup.
#     321     # Beautiful Soup will still parse the input as markup,
#     322     # since that is sometimes the intended behavior.
# ...

# %%
response_data = value.json()

# Extract information from the response
if 'items' in response_data:
    for item in response_data['items']:
        title = item.get('title', 'No title')
        link = item.get('link', 'No link')
        snippet = item.get('snippet', 'No snippet')
        print("Title:", title)
        print("Link:", link)
        print("Snippet:", snippet)
        
else:
    print("No search results found.")
# Out:
# Title: Fastest Cars In The World Ranked
# Link: https://www.topspeed.com/fastest-cars-in-the-world-ranked/
# Snippet: Aug 2, 2023 ... Top Speed: 268 mph ... The Bugatti Veyron may be 17 years old as of 2022, but it's still among the fastest supercars ever built. Actually, the ...
# Title: Fastest Cars In The World (2023 Update) | Motor1.com
# Link: https://www.motor1.com/features/459605/fastest-cars-in-the-world/
# Snippet: Apr 28, 2023 ... The Bugatti Chiron Super Sport 300+ is technically the fastest car in the world with an achieved top speed of 304.8 mph. Its quadruple- ...
# Title: Top 10 Fastest Cars in the World | SIXT rent a car Magazine
# Link: https://www.sixt.com/magazine/tips/top-10-fastest-cars-in-the-world/
# Snippet: Top 10 Fastest Cars in the World · 1. BUGATTI BOLIDE : +310 MPH (Estimated) · 2. BUGATTI CHIRON SUPER SPORT 300+ : 304 MPH · 3. KOENIGSEGG JESKO ABSOLUTE: 300 MPH.
# Title: Production car speed record - Wikipedia
# ...

# %%
print(type(response_data))
# Out:
# <class 'dict'>

# %%
fin=[]
for vals in response_data:
    fin.append(vals)
fin
# Out:
# ['kind', 'url', 'queries', 'context', 'searchInformation', 'items']

# %%
# for majina in fin:
#     jina=str(majina)
#     for kin in response_data[jina]:
#         print(kin)


    
f=response_data['items']
print(type(f))
fg=f[7]
fg.get('link')
print(fg.keys())
print(fg.get('formattedUrl'))
# Out:
# <class 'list'>
# dict_keys(['kind', 'title', 'htmlTitle', 'link', 'displayLink', 'snippet', 'htmlSnippet', 'cacheId', 'formattedUrl', 'htmlFormattedUrl', 'pagemap'])
# https://www.automoblog.net/top-10-fastest-cars-in-the-world/

# %%
for g in f:
    print(g)
# Out:
# {'kind': 'customsearch#result', 'title': 'Fastest Cars In The World Ranked', 'htmlTitle': '<b>Fastest Cars</b> In The World Ranked', 'link': 'https://www.topspeed.com/fastest-cars-in-the-world-ranked/', 'displayLink': 'www.topspeed.com', 'snippet': "Aug 2, 2023 ... Top Speed: 268 mph ... The Bugatti Veyron may be 17 years old as of 2022, but it's still among the fastest supercars ever built. Actually, the\xa0...", 'htmlSnippet': 'Aug 2, 2023 <b>...</b> <b>Top</b> Speed: 268 mph ... The Bugatti Veyron may be 17 years old as of 2022, but it&#39;s still among the <b>fastest</b> supercars ever built. Actually, the&nbsp;...', 'cacheId': '9VgqSao2eggJ', 'formattedUrl': 'https://www.topspeed.com/fastest-cars-in-the-world-ranked/', 'htmlFormattedUrl': 'https://www.<b>top</b>speed.com/<b>fastest</b>-<b>cars</b>-in-the-world-ranked/', 'pagemap': {'cse_thumbnail': [{'src': 'https://encrypted-tbn2.gstatic.com/images?q=tbn:ANd9GcQkbMQ9u5q31L_7CAwqzQ3k877BxuqZ4Fq7AJhE7X_y3UsP1Q1Er_2m6B65', 'width'
# ...

# %%
maxwebsites=5
website=[]
for i in range(maxwebsites):
    loop_var=f[i]
    loop_var2=loop_var['formattedUrl']
    website.append(loop_var2)
website
# Out:
# ['https://www.topspeed.com/fastest-cars-in-the-world-ranked/',
#  'https://www.motor1.com/features/459605/fastest-cars-in-the-world/',
#  'https://www.sixt.com/magazine/tips/top-10-fastest-cars-in-the-world/',
#  'https://en.wikipedia.org/wiki/Production_car_speed_record',
#  'https://www.carwow.co.uk/blog/fastest-cars-in-the-world']

# %%
wiki_link=website[3]

first=requests.get(wiki_link)
# Out:
# <bound method Response.json of <Response [200]>>

# %%
soup=sp(first.content,'html.parser')
soup.prettify()
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled" dir="ltr" lang="en">\n <head>\n  <meta charset="utf-8"/>\n  <title>\n   Production car speed record - Wikipedia\n  </title>\n  <script>\n   (function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled";var cookie=document.cookie.m
# ...

# %%
tables = soup.find_all('table')
tables
# Out:
# [<table class="wikitable sortable">
#  <tbody><tr>
#  <th>Year
#  </th>
#  <th>Make and model
#  </th>
#  <th>Top speed
#  </th>
#  <th>Engine
#  </th>
#  <th>Number built
#  </th>
#  <th>Comment
#  </th></tr>
#  <tr>
#  <td>1894
#  </td>
#  <td><a href="/wiki/Benz_Velo" title="Benz Velo">Benz Velo</a>
#  </td>
#  <td>20 km/h (12 mph)<sup class="reference" id="cite_ref-3"><a href="#cite_note-3">[3]</a></sup>
#  </td>
#  <td>1,045 cm<sup>3</sup> (63.8 cu in) single-cylinder 1.1 kW (1.5 PS; 1.5 bhp)
#  </td>
#  <td>1,200
#  </td>
#  <td>First production car
#  </td></tr>
#  <tr>
#  <td>1949
#  </td>
#  <td><a href="/wiki/Jaguar_XK120" title="Jaguar XK120">Jaguar XK120</a>
#  </td>
#  <td>200.5 km/h (124.6 mph)<sup class="reference" id="cite_ref-aw20121015_4-0"><a href="#cite_note-aw20121015-4">[4]</a></sup>
#  </td>
#  <td>3,442 cm<sup>3</sup> (210.0 cu in) inline-6 119 kW (162 PS; 160 hp)
#  </td>
#  <td>12,000
#  </td>
# ...

# %%
import pandas as pd

# %%
kichwa=[]
for it in tables:
    rows = it.find_all('tr')
    for row in rows:
        data = []
        columndata = row.find_all(['td'])
        columnhead=row.find_all('th')
        for lk in columnhead:
            ui=lk.get_text().strip()
            kichwa.append(ui)
            

            
namba=6    
firstT=[]
secondT=[]
for i in range(namba):
    fa=kichwa[i]
    firstT.append(fa)
lenk=len(kichwa)
for i in range(6,lenk):
    fb=kichwa[i]
    secondT.append(fb)
daf=pd.DataFrame(columns=firstT)
daf2=pd.DataFrame(columns=secondT)
print(len(firstT))
# Out:
# 6

# %%
content=[]
content2=[]
for it in tables:
    rows = it.find_all('tr')
    
    for row in rows:
        data = []
        columndata = row.find_all(['td'])
        row_data = []  # Initialize an empty list to hold the data of the current row

#         for cell in columndata:
#             cell_text = cell.get_text(strip=True)  # Extract text content from the cell
#             row_data.append(cell_text)  # Add the extracted text to the row_data list

#         print(row_data) 
#         jk=columndata.get_text.strip()
#         print(columndata)
#         if len(columndata)==6:
#             content.append(columndata)
#         columnhead=row.find_all('th')
        for lk in columndata:
            ui=lk.get_text(strip=True)
            row_data.append(ui)
#             content.append(ui)
        content.append(row_data)
    
print(len(content))
content
# Out:
# 69
# [[],
#  ['1894',
#   'Benz Velo',
#   '20\xa0km/h (12\xa0mph)[3]',
#   '1,045\xa0cm3(63.8\xa0cu\xa0in) single-cylinder 1.1\xa0kW (1.5\xa0PS; 1.5\xa0bhp)',
#   '1,200',
#   'First production car'],
#  ['1949',
#   'Jaguar XK120',
#   '200.5\xa0km/h (124.6\xa0mph)[4]',
#   '3,442\xa0cm3(210.0\xa0cu\xa0in) inline-6 119\xa0kW (162\xa0PS; 160\xa0hp)',
#   '12,000',
#   "Some publications cite the XK120's timed top speed as almost 214\xa0km/h (133\xa0mph) in 1949.[5]The XK120 that achieved this speed was a tuned prototype, not a production car. The production car reached 200.5\xa0km/h (124.6\xa0mph)."],
#  ['1955',
#   'Mercedes-Benz 300SL',
#   '242.5\xa0km/h (150.7\xa0mph)[6]',
#   '2,996\xa0cm3(182.8\xa0cu\xa0in) inline-6 158\xa0kW (215\xa0PS; 212\xa0hp)',
#   '1,400',
#   'Two-way average speed tested byAutomobil Revuein 1958. 245\xa0km/h (152.2\xa0mph) reached in one direction.'],
#  ['1959',
#   'Aston Martin DB4GT',
#   '245\xa0km/h (152\xa0mph)[7]',
# ...

# %%
ro=[]
for ta in content:
    if len(ta)==6:
        ro.append(ta)
        
ro
daaf=pd.DataFrame(ro,columns=firstT)
daaf["km/h"] = daaf["Top speed"].str.extract(r'(\d+\.\d+|\d+)').astype(float)
# engine_pattern = r'(\d+(?:,\d{3})*) cm3.*?([a-zA-Z\- ]+) (\d+(?:\.\d+)?) kW \(\d+(?:\.\d+)? PS; (\d+(?:\.\d+)?) hp\)'

# engine_data = daaf["Engine"].str.extract(engine_pattern)
# print(engine_data[0])

# Assign extracted components to separate columns
# daaf["Size (cm3)"] = engine_data[0].str.replace(',', '').astype(int)
# daaf["Engine Type"] = engine_data[1]
# daaf["PS"] = engine_data[3].astype(float)
# daaf["Horsepower (hp)"] = engine_data[4].astype(float)
daaf
# Out:
#     Year                   Make and model                         Top speed  \
# 0   1894                        Benz Velo               20 km/h (12 mph)[3]
# 1   1949                     Jaguar XK120         200.5 km/h (124.6 mph)[4]
# 2   1955              Mercedes-Benz 300SL         242.5 km/h (150.7 mph)[6]
# 3   1959               Aston Martin DB4GT             245 km/h (152 mph)[7]
# 4   1963                  Iso GrifoGL 365             259 km/h (161 mph)[8]
# 5   1965               AC CobraMk III 427            266 km/h (165 mph)[10]
# 6   1967            Lamborghini MiuraP400            275 km/h (171 mph)[11]
# 7   1968        Ferrari 365 GTB/4 Daytona            280 km/h (174 mph)[12]
# 8   1969           Lamborghini MiuraP400S        288.6 km/h (179.3 mph)[13]
# 9   1982     Lamborghini Countach LP500 S            293 km/h (182 mph)[14]
# 10  1983                          Ruf BTR            305 km/h (190 mph)[15]
# ...

# %%
engine_components= daaf["Engine"].str.split(expand=True)

# Rename columns for clarity
# engine_components.columns = ["Size (cm3)", "cm3", "Engine Type", "kW", "PS;", "PS", "hp;", "hp"]

# # Convert relevant columns to numeric
# engine_components["Size (cm3)"] = engine_components["Size (cm3)"].str.replace(',', '').astype(int)
# engine_components["kW"] = engine_components["kW"].astype(float)
# engine_components["PS"] = engine_components["PS"].str.replace(';', '').astype(float)
# engine_components["hp"] = engine_components["hp"].str.replace(';', '').astype(float)
daaf['sizein Cm3']=engine_components[0]
daaf['enginetype']=engine_components[4]
# engine_components
# sdf = engine_components[9].apply(lambda x: sdf_10[int(x) - 1] if isinstance(x, int) else x)
#replace('PS', engine_components[10][engine_components[10].apply(lambda x: isinstance(x, int))])
daaf
# sdf=engine_components[10]
# print(type(engine_components[10]))
zx=engine_components[9]
bv=engine_components[10]
nm=[]
for g in zx:
    
    if g is None:
        nm.append(None)  # Append 'None' as is
    elif g.replace(".", "", 1).isdigit():
        nm.append(int(float(g)))  # Convert and append as integer
    elif g.lower() == 'none':
        nm.append(float('nan'))  # Append 'None' as is
    else:
        nm.append(float('nan'))  # Append 'nan' as a float
        
        
print(bv,zx)
# Out:
# 0      bhp)
# 1       hp)
# 2       hp)
# 3       hp)
# 4       hp)
# 5       hp)
# 6       hp)
# 7       hp)
# 8       hp)
# 9       hp)
# 10      369
# 11      444
# 12      463
# 13      720
# 14      987
# 15     None
# 16    1,183
# 17    1,341
# 18     bhp)
# 19     bhp)
# 20      hp)
# 21      625
# 22      542
# 23      806
# 24    1,244
# 25    1,578
# 26    1,750
# Name: 10, dtype: object 0      1.5
# 1      160
# 2      212
# 3      302
# 4      360
# 5      485
# 6      350
# 7      352
# 8      370
# 9      375
# 10     PS;
# 11     PS;
# 12     PS;
# 13     PS;
# 14     PS;
# 15    None
# 16     PS;
# 17     PS;
# 18     360
# 19     340
# 20     449
# 21     PS;
# 22     PS;
# 23     PS;
# 24     PS;
# 25     PS;
# 26     PS;
# Name: 9, dtype: object

# %%
daaf
# Out:
#     Year                   Make and model                         Top speed  \
# 0   1894                        Benz Velo               20 km/h (12 mph)[3]
# 1   1949                     Jaguar XK120         200.5 km/h (124.6 mph)[4]
# 2   1955              Mercedes-Benz 300SL         242.5 km/h (150.7 mph)[6]
# 3   1959               Aston Martin DB4GT             245 km/h (152 mph)[7]
# 4   1963                  Iso GrifoGL 365             259 km/h (161 mph)[8]
# 5   1965               AC CobraMk III 427            266 km/h (165 mph)[10]
# 6   1967            Lamborghini MiuraP400            275 km/h (171 mph)[11]
# 7   1968        Ferrari 365 GTB/4 Daytona            280 km/h (174 mph)[12]
# 8   1969           Lamborghini MiuraP400S        288.6 km/h (179.3 mph)[13]
# 9   1982     Lamborghini Countach LP500 S            293 km/h (182 mph)[14]
# 10  1983                          Ruf BTR            305 km/h (190 mph)[15]
# ...

# %%
wq=daaf[]

# %%
data_list = []
column_headers = []

# Loop through rows
for row in tables:
    row_data = []
    cells = row.find_all(['th', 'td'])
    
    for cell in cells:
        row_data.append(cell.get_text().strip())
        
        # Capture column headers
        if cell.name == 'th':
            column_headers.append(cell.get_text().strip())
    
    if row_data:
        data_list.append(row_data)

# Create a pandas DataFrame
df = pd.DataFrame(data_list, columns=column_headers)
df
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:969, in _finalize_columns_and_data(content, columns, dtype)
#     968 try:
# --> 969     columns = _validate_or_indexify_columns(contents, columns)
#     970 except AssertionError as err:
#     971     # GH#26429 do not raise user-facing AssertionError
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\construction.py:1017, in _validate_or_indexify_columns(content, columns)
#    1015 if not is_mi_list and len(columns) != len(content):  # pragma: no cover
#    1016     # caller's responsibility to check for this...
# -> 1017     raise AssertionError(
#    1018         f"{len(columns)} columns passed, passed data had "
#    1019         f"{len(content)} columns"
#    1020     )
#    1021 elif is_mi_list:
#    1022
# ...

# %%
data_list = []
column_headers = []

# Loop through rows
for row in tables:
    row_data = []
    cells = row.find_all(['th', 'td'])
    
    for cell in cells:
        row_data.append(cell.get_text().strip())
    
    if row_data:
        data_list.append(row_data)

# Find the maximum number of columns
max_columns = max(len(row) for row in data_list)

# Fill missing cells with empty strings
for row in data_list:
    while len(row) < max_columns:
        row.append("")

# Create a pandas DataFrame
df = pd.DataFrame(data_list, columns=[f"Column{i+1}" for i in range(max_columns)])

df
# Out:
#                                              Column1  \
# 0                                               Year
# 1                                               Year
# 2                              vteExtremes of motion
# 3                                         vteRecords
# 4  Chess\nCricket\nTest\nOne Day International\nT...
# 5                                              Speed
# 6                                 Wave\nLight\nSound
#
#                                              Column2  \
# 0                                     Make and model
# 1                                     Make and model
# 2                                              Speed
# 3                                      World records
# 4                                          Athletics
# 5  Wave\nLight\nSound\nVehicle\nSpacecraft\nAircr...
# 6                                            Vehicle
#
#                                              Column3        Column4  \
# ...
